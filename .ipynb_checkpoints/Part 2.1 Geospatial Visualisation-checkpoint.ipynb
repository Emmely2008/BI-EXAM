# %%
##Part 2 2.1

# %matplotlib notebook


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
    
     
complete_data = './scraped_events_preproc.csv'

df = pd.read_csv(complete_data)


df_top_ten = df.groupby(['Where','lon','lat'])['Where'].agg(
    {"count": len}).sort_values(
    "count", ascending=False).head(10).reset_index()
print(df_top_freq)


import folium


my_map = folium.Map(location=[55.88207495748612, 10.636574309440173], zoom_start=6)

for coords in zip(df_top_freq.lon.values, 
                  df_top_freq.lat.values):
    print(coords)##For some reasons they all got the same coordinates
    folium.CircleMarker(location=[coords[1], coords[0]], radius=2).add_to(my_map)
my_map.save('venue_locs.html')
my_map
# Out:
# /home/vagrant/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   from ipykernel import kernelapp as app
#                                                Where        lon        lat  \
# 0  Koncerthuset DR, DR Byen, Emil Holms Kanal 20,...  12.351919  55.615542
# 1                  VEGA, Enghavevej 40, Copenhagen V  12.351919  55.615542
# 2          Metronomen, Godthåbsvej 33, Frederiksberg  12.351919  55.615542
# 3   Kulturhuset Viften, Rødovre Parkvej 130, Rødovre  12.351919  55.615542
# 4          Pumpehuset, Studiestræde 52, Copenhagen V  12.351919  55.615542
# 5       Ishøj Kultur Café, Ishøj Østergade 28, Ishøj  12.351919  55.615542
# 6             Ideal Bar, Enghavevej 40, Copenhagen V  12.351919  55.615542
# 7  Mojo Blues bar, Løngangsstræde 21 C, Copenhagen K  12.351919  55.615542
# ...
